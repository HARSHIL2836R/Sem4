# %%
import numpy as np
import copy
import matplotlib.pyplot as plt
import torch.nn as nn
import torch
import torch.optim as optim
import sklearn
from sklearn import metrics as metrics
import pandas as pd
import calc_probability

# %%
for i in range(0,5):
    dealer_data = calc_probability.data_loader("train.csv", i, "dealer")
    dealer_cards=dealer_data[:,1]
    prob = calc_probability.bust_probability(dealer_cards)
    print(f"Bust Probability for table {i+1} is {prob}")
# Out:
# Bust Probability for table 1 is {0.6299883119051595, np.float64(22.20988478877943)}
# Bust Probability for table 2 is {0.3217680608365019, np.float64(20.480038022813687)}
# Bust Probability for table 3 is {0.3082997311827957, np.float64(20.284442204301076)}
# Bust Probability for table 4 is {0.24729353541602228, np.float64(20.231673368388492)}
# Bust Probability for table 5 is {0.0016501650165016502, np.float64(19.234773477347733)}
